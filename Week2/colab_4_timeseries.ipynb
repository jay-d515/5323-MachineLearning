# %% [markdown]
# # Utilize the time of data capture for data preprocessing
#
# Address irregular intervals, generalize the model to different seasons, and create consistency between features from different seasons

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt

# %%
pd.__version__
# Out:
# '1.5.3'

# %% [markdown]
# ## Data preparation

# %%
df = pd.read_csv('cc1.csv')
df.shape
# Out:
# (875, 41)

# %% [markdown]
# ## Features names (columns names)

# %%
# columns = ['cc_0412', 'cc_0415', 'cc_0427', 'cc_0506', 'cc_0516', 'cc_0520', 'cc_0523', 'cc_0527', 'cc_0531', 'cc_0602',
#        'cc_0607', 'cc_0614', 'cc_0617', 'cc_0620', 'cc_0623', 'cc_0627',
#        'cc_0630', 'cc_0708', 'cc_0713', 'cc_0716', 'cc_0719', 'cc_0721',
#        'cc_0725', 'cc_0728', 'cc_0802', 'cc_0808', 'cc_0812']

# len(columns)

# %% [markdown]
# ## Split dataframe into X, y before further processing

# %%
# separating the data to X and y
X = df[['cc_0412', 'cc_0415', 'cc_0427', 'cc_0506', 'cc_0516', 'cc_0520', 'cc_0523', 'cc_0527', 'cc_0531', 'cc_0602',
       'cc_0607', 'cc_0614', 'cc_0617', 'cc_0620', 'cc_0623', 'cc_0627',
       'cc_0630', 'cc_0708', 'cc_0713', 'cc_0716', 'cc_0719', 'cc_0721',
       'cc_0725', 'cc_0728', 'cc_0802', 'cc_0808', 'cc_0812']]

y = df['Weight per row (lbs)']

# %% [markdown]
# ## Creating capture dates as datetime column and then make it dataframe index

# %%
# generate the time series 
# cc_0412	cc_0415	cc_0427	cc_0506	cc_0516	cc_0520	cc_0523	cc_0527	cc_0531	cc_0602	cc_0607	cc_0614	cc_0617	cc_0620	cc_0623	cc_0627	cc_0630	cc_0708	cc_0713	cc_0716	cc_0719	cc_0721	cc_0725	cc_0728	cc_0802	cc_0808	cc_0812
capture_date = ['4/12/2018', '4/15/2018', '4/27/2018', '5/6/2018', '5/16/2018', '5/20/2018', '5/23/2018', '5/27/2018', 
                '5/31/2018', '6/2/2018','6/7/2018', '6/14/2018', '6/17/2018', '6/20/2018', '6/23/2018', '6/27/2018', 
                '6/30/2018', '7/8/2018', '7/13/2018', '7/16/2018', '7/19/2018', '7/21/2018', 
                '7/25/2018', '7/28/2018', '8/2/2018', '8/8/2018', '8/12/2018']
capture_date = pd.to_datetime(capture_date)
capture_date
# len(capture_date)
# Out:
# DatetimeIndex(['2018-04-12', '2018-04-15', '2018-04-27', '2018-05-06',
#                '2018-05-16', '2018-05-20', '2018-05-23', '2018-05-27',
#                '2018-05-31', '2018-06-02', '2018-06-07', '2018-06-14',
#                '2018-06-17', '2018-06-20', '2018-06-23', '2018-06-27',
#                '2018-06-30', '2018-07-08', '2018-07-13', '2018-07-16',
#                '2018-07-19', '2018-07-21', '2018-07-25', '2018-07-28',
#                '2018-08-02', '2018-08-08', '2018-08-12'],
#               dtype='datetime64[ns]', freq=None)

# %%
X_Transpose = X.T
# X_Transpose.shape
X_Transpose['capture_date'] = capture_date
X_Transpose.set_index(['capture_date'])
# X_Transpose
# Out:
#                     0           1           2          3          4    \
# capture_date
# 2018-04-12     0.081568    0.186077    0.661464   0.336467   0.067548
# 2018-04-15     0.021485    0.012533    0.134284   0.044761   0.016114
# 2018-04-27     0.506667    3.188473    5.517654   1.549694   0.807326
# 2018-05-06     0.673716    1.353307    2.679195   2.653735   1.306303
#
# File D:\Users\Mahmoud\anaconda3\Lib\site-packages\pandas\core\frame.py:11367, in DataFrame.asfreq(self, freq, method, how, normalize, fill_value)
#   11358 @doc(NDFrame.asfreq, **_shared_doc_kwargs)
#   11359 def asfreq(
#   11360     self,
#    (...)
#   11365     fill_value: Hashable = None,
#   11366 ) -> DataFrame:
# > 11367     return super().asfreq(
#   11368         freq=freq,
#   11369         method=method,
#   11370         how=how,
#   11371         normalize=normalize,
#   11372         fill_value=fill_value,
#   11373     )
#
# File D:\Users\Mahmoud\anaconda3\Lib\site-packages\pandas\core\generic.py:8235, in NDFrame.asfreq(self, freq, method, how, normalize, fill_value)
#    8128 """
#    8129 Convert time series to specified frequency.
#    8130
#    (...)
#    8231 2000-01-01 00:03:00    3.0
#    8232 """
#    8233 from pandas.core.resample import asfreq
# -> 8235 return asfreq(
#    8236     self,
#    8237     freq,
#    8238     method=method,
#    8239     how=how,
#    8240     normalize=normalize,
#    8241     fill_value=fill_value,
#    8242 )
#
# File D:\Users\Mahmoud\anaconda3\Lib\site-packages\pandas\core\resample.py:2229, in asfreq(obj, freq, method, how, normalize, fill_value)
#    2227     new_obj.index = _asfreq_compat(obj.index, freq)
#    2228 else:
# -> 2229     dti = date_range(obj.index.min(), obj.index.max(), freq=freq)
#    2230     dti.name = obj.index.name
#    2231     new_obj = obj.reindex(dti, method=method, fill_value=fill_value)
#
# File D:\Users\Mahmoud\anaconda3\Lib\site-packages\pandas\core\indexes\datetimes.py:1125, in date_range(start, end, periods, freq, tz, normalize, name, closed, inclusive, **kwargs)
#    1122 if freq is None and com.any_none(periods, start, end):
#    1123     freq = "D"
# -> 1125 dtarr = DatetimeArray._generate_range(
#    1126     start=start,
#    1127     end=end,
#    1128     periods=periods,
#    1129     freq=freq,
#    1130     tz=tz,
#    1131     normalize=normalize,
#    1132     inclusive=inclusive,
#    1133     **kwargs,
#    1134 )
#    1135 return DatetimeIndex._simple_new(dtarr, name=name)
#
# File D:\Users\Mahmoud\anaconda3\Lib\site-packages\pandas\core\arrays\datetimes.py:361, in DatetimeArray._generate_range(cls, start, end, periods, freq, tz, normalize, ambiguous, nonexistent, inclusive)
#     358 freq = to_offset(freq)
#     360 if start is not None:
# --> 361     start = Timestamp(start)
#     363 if end is not None:
#     364     end = Timestamp(end)
#
# File D:\Users\Mahmoud\anaconda3\Lib\site-packages\pandas\_libs\tslibs\timestamps.pyx:1698, in pandas._libs.tslibs.timestamps.Timestamp.__new__()
#
# File D:\Users\Mahmoud\anaconda3\Lib\site-packages\pandas\_libs\tslibs\conversion.pyx:249, in pandas._libs.tslibs.conversion.convert_to_tsobject()
#
# File D:\Users\Mahmoud\anaconda3\Lib\site-packages\pandas\_libs\tslibs\conversion.pyx:533, in pandas._libs.tslibs.conversion._convert_str_to_tsobject()
#
# ValueError: could not convert string to Timestamp

# %%
# X_Transpose.interpolate('linear')

# %%
# X_Transpose = X_Transpose.interpolate(method='linear')

# %%
X_Transpose = X_Transpose.interpolate(method='linear')
# X_Transpose = X_Transpose.asfreq('5858T')
X = X_Transpose.T
X = X.iloc[:-1, :]

# %%
X_transpose.columns

# %%
X.describe()

# %%
X_raw = df[['cc_0412', 'cc_0415', 'cc_0427', 'cc_0506', 'cc_0516', 'cc_0520', 'cc_0523', 'cc_0527', 'cc_0531', 'cc_0602',
       'cc_0607', 'cc_0614', 'cc_0617', 'cc_0620', 'cc_0623', 'cc_0627',
       'cc_0630', 'cc_0708', 'cc_0713', 'cc_0716', 'cc_0719', 'cc_0721',
       'cc_0725', 'cc_0728', 'cc_0802', 'cc_0808', 'cc_0812']]

X_raw.describe()

# %% [markdown]
# ## a better solution is to inspect interpolation for couple examples

# %%
X.head(2)

# %%
X_raw.head(2)

# %% [markdown]
# ## Sanity check for nan

# %%
X.isna().sum().sum()

# %% [markdown]
# ## Split the data into training and testing

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=1)

# %% [markdown]
# ## Modeling and training

# %%
reg = LinearRegression().fit(X_train, y_train)
y_hat = reg.predict(X_test)

# %% [markdown]
# ## Evaluation

# %%
reg.score(X_test, y_test)

# %%
# Resources
# https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html
# https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html
